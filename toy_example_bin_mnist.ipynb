# %% [markdown]
# # Toy Example for Dirichlet Diffusion Score Model

# %% [markdown]
# In this notebook demo, we provide a quick demo on binarized MNIST dataset. Let's load required libraries first.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %reload_ext autoreload

# %%
import os

try:
    with open(".env") as f:
        for line in f:
            key, value = line.strip().split('=', 1)
            os.environ[key] = value
except FileNotFoundError:
    pass

# %%
WANDB_ENTITY = os.environ.get("WANDB_ENTITY", "default-entity")
WANDB_PROJECT = os.environ.get("WANDB_PROJECT", "DDSM_testing")

# %%
import wandb

# %%
import os
from matplotlib import pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torchvision.transforms as transforms


import torch
import functools
from torch.optim import Adam
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torchvision.datasets import MNIST
from torchvision.utils import make_grid
import tqdm


import pandas as pd
import functools
import numpy as np

# Main file which contrains all DDSM logic
from ddsm import *

# %%
from utils import get_best_device

device = get_best_device()
print(f"Using device: {device}")
# Out:
# Using device: mps

# %% [markdown]
# ### Loading Presampled Noise

# %% [markdown]
# While Jacobi diffusion evaluation is more expensive than the commonly used diffusion process with Gaussian stationary distribution, all Jacobi diffusion-related computations can be precomputed prior to training and do not add to training time. This is feasible because we only need to generate samples from two starting points, 0 and 1, for any categorical data. Training time sampling is done by choosing randomly from the pre-sampled samples and scores.
#
# For presampling weights, you need to presample everything by running ''presample_noise.py'' script provided in the repo. For example,
# ```
# python presample_noise.py -n 10000 -c 2 -t 400 --out_path . --mode path
# ```
# generates file with 2 categories, 10000 samples, and 400 timepoints. This noise will be used later for training, sampling, and computing negative log likelihood.
#
# Let's load generated file.

# %%
# !python presample_noise.py -n 10000 -c 2 -t 400 --out_path . --mode path
# Out:
# 100%|█████████████████████████████████████████| 400/400 [05:42<00:00,  1.17it/s]

# %%
v_one, v_zero, v_one_loggrad, v_zero_loggrad, timepoints = torch.load("steps400.cat2.time4.0.samples10000.pth")

# We have two categories, so the beta parameters are 
alpha = torch.Tensor([1.0])
beta = torch.Tensor([1.0])

# Example of 4 categories to be used with diffusion_factory
# alpha = torch.Tensor([1.0, 1.0, 1.0])
# beta = torch.Tensor([3.0, 2.0, 1.0])

# %% [markdown]
# ### Defining the Model
#
# Now, let's define the score-based model for binarized MNIST data.

# %%
# Model architecture borrowed from https://github.com/yang-song/score_sde
# Note the manuscript experiment on binarized MNIST use a different, larger model

class Dense(nn.Module):
    """
    A fully connected layer that reshapes outputs to feature maps.
    """
    def __init__(self, input_dim, output_dim):
        super().__init__()
        self.dense = nn.Linear(input_dim, output_dim)

    def forward(self, x):
        return self.dense(x)[..., None, None]


class ScoreNet(nn.Module):
    """A time-dependent score-based model built upon U-Net architecture."""
    def __init__(self, channels=[32, 64, 128, 256], embed_dim=256):
        """Initialize a time-dependent score-based network.

        Args:
          marginal_prob_std: A function that takes time t and gives the standard
            deviation of the perturbation kernel p_{0t}(x(t) | x(0)).
          channels: The number of channels for feature maps of each resolution.
          embed_dim: The dimensionality of Gaussian random feature embeddings.
        """
        super().__init__()
        # Gaussian random feature embedding layer for time
        self.embed = nn.Sequential(
            GaussianFourierProjection(embed_dim=embed_dim),
            nn.Linear(embed_dim, embed_dim),
        )
        
        # Encoding layers where the resolution decreases
        self.conv1 = nn.Conv2d(2, channels[0], 3, stride=1, bias=False)
        self.dense1 = Dense(embed_dim, channels[0])
        self.gnorm1 = nn.GroupNorm(4, num_channels=channels[0])
        self.conv2 = nn.Conv2d(channels[0], channels[1], 3, stride=2, bias=False)
        self.dense2 = Dense(embed_dim, channels[1])
        self.gnorm2 = nn.GroupNorm(32, num_channels=channels[1])
        self.conv3 = nn.Conv2d(channels[1], channels[2], 3, stride=2, bias=False)
        self.dense3 = Dense(embed_dim, channels[2])
        self.gnorm3 = nn.GroupNorm(32, num_channels=channels[2])
        self.conv4 = nn.Conv2d(channels[2], channels[3], 3, stride=2, bias=False)
        self.dense4 = Dense(embed_dim, channels[3])
        self.gnorm4 = nn.GroupNorm(32, num_channels=channels[3])

        # Decoding layers where the resolution increases
        self.tconv4 = nn.ConvTranspose2d(
            channels[3], channels[2], 3, stride=2, bias=False
        )
        
        self.dense5 = Dense(embed_dim, channels[2])
        self.tgnorm4 = nn.GroupNorm(32, num_channels=channels[2])
        self.tconv3 = nn.ConvTranspose2d(
            channels[2] + channels[2],
            channels[1],
            3,
            stride=2,
            bias=False,
            output_padding=1,
        )
        
        self.dense6 = Dense(embed_dim, channels[1])
        self.tgnorm3 = nn.GroupNorm(32, num_channels=channels[1])
        self.tconv2 = nn.ConvTranspose2d(
            channels[1] + channels[1],
            channels[0],
            3,
            stride=2,
            bias=False,
            output_padding=1,
        )
        self.dense7 = Dense(embed_dim, channels[0])
        self.tgnorm2 = nn.GroupNorm(32, num_channels=channels[0])
        self.tconv1 = nn.ConvTranspose2d(channels[0] + channels[0], 2, 3, stride=1)

        # The swish activation function
        self.act = lambda x: x * torch.sigmoid(x)

    def forward(self, x, t):
        # Obtain the Gaussian random feature embedding for t
        embed = self.act(self.embed(t / 4.0))
        # Encoding path
        h1 = self.conv1(x.permute(0, 3, 1, 2))
        ## Incorporate information from t
        h1 += self.dense1(embed)
        h1 = self.gnorm1(h1)
        h1 = self.act(h1)
        h2 = self.conv2(h1)
        h2 += self.dense2(embed)
        h2 = self.gnorm2(h2)
        h2 = self.act(h2)
        h3 = self.conv3(h2)
        h3 += self.dense3(embed)
        h3 = self.gnorm3(h3)
        h3 = self.act(h3)
        h4 = self.conv4(h3)
        h4 += self.dense4(embed)
        h4 = self.gnorm4(h4)
        h4 = self.act(h4)

        # Decoding path
        h = self.tconv4(h4)
        ## Skip connection from the encoding path
        h += self.dense5(embed)
        h = self.tgnorm4(h)
        h = self.act(h)
        h = self.tconv3(torch.cat([h, h3], dim=1))
        h += self.dense6(embed)
        h = self.tgnorm3(h)
        h = self.act(h)
        h = self.tconv2(torch.cat([h, h2], dim=1))
        h += self.dense7(embed)
        h = self.tgnorm2(h)
        h = self.act(h)
        h = self.tconv1(torch.cat([h, h1], dim=1))

        # some scaling here by time or x may be helpful but no scaling works fine here
        h = h.permute(0, 2, 3, 1)
        h = h - h.mean(axis=-1, keepdims=True)
        return h

# %% [markdown]
# ### Loading Binarized Mnist Data
#
# The following code load MNIST data and create binarized version of it.

# %%
# !mkdir -p mnist

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

import os
import joblib
import numpy as np
from urllib.request import urlretrieve


def load_mnist_binarized(root):
    datapath = os.path.join(root, "bin-mnist")
    if not os.path.exists(datapath):
        os.makedirs(datapath)
    dataset = os.path.join(datapath, "mnist.pkl.gz")

    if not os.path.isfile(dataset):

        datafiles = {
            "train": "http://www.cs.toronto.edu/~larocheh/public/"
            "datasets/binarized_mnist/binarized_mnist_train.amat",
            "valid": "http://www.cs.toronto.edu/~larocheh/public/datasets/"
            "binarized_mnist/binarized_mnist_valid.amat",
            "test": "http://www.cs.toronto.edu/~larocheh/public/datasets/"
            "binarized_mnist/binarized_mnist_test.amat",
        }
        datasplits = {}
        for split in datafiles.keys():
            print("Downloading %s data..." % (split))
            datasplits[split] = np.loadtxt(urlretrieve(datafiles[split])[0])

        joblib.dump(
            [datasplits["train"], datasplits["valid"], datasplits["test"]],
            open(dataset, "wb"),
        )

    x_train, x_valid, x_test = joblib.load(open(dataset, "rb"))
    return x_train, x_valid, x_test


class BinMNIST(Dataset):
    """Binary MNIST dataset"""

    def __init__(self, data, device="cpu", transform=None):
        h, w, c = 28, 28, 1
        self.device = device
        self.data = torch.tensor(data, dtype=torch.float).view(-1, c, h, w)
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = self.data[idx]
        if self.transform:
            sample = self.transform(sample)
        return sample.to(self.device)


def get_binmnist_datasets(root, device="cpu"):
    x_train, x_valid, x_test = load_mnist_binarized(root)
    # x_train = np.append(x_train, x_valid, axis=0)  # https://github.com/casperkaae/LVAE/blob/master/run_models.py (line 401)
    return (
        BinMNIST(x_train, device=device),
        BinMNIST(x_valid, device=device),
        BinMNIST(x_test, device=device),
    )


def binary_to_onehot(x):
    xonehot = []
    xonehot.append((x == 1)[..., None])
    xonehot.append((x == 0)[..., None])
    return torch.cat(xonehot, -1)

train_set, valid_set, test_set = get_binmnist_datasets("./mnist")

# %% [markdown]
# Let's load training/validation/test datasets and dataset for importance sampling weights estimation.

# %%
batch_size = 32

# %%
weights_est_dl = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=0)

# %%
training_dl = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=0)

# %%
valid_data_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=False, num_workers=0)
valid_datasets = []
for x in valid_data_loader:
    valid_datasets.append(x)

# %%
test_dl = DataLoader(test_set, batch_size=batch_size, shuffle=True, num_workers=0)

# %% [markdown]
# ### Global Parameters
#
# We define a few global parameters for our model

# %%
device
# Out:
# device(type='mps')

# %%
# number of categories are 2 for binarized MNIST data
C = 2

# setting speed_balanced does not have an effect for C=2
# For >2 categories, setting speed_balanced flag affects the convergence speed of the forward diffusion. 
# (see Appendix A.2)
# speed_balanced = True leads to similar convergence speed across individual univariate Jacobi diffusion processes
# speed balanced = False leads to similar convergence speed across different categories after stick breaking transform

speed_balanced = False  

if speed_balanced:
    s = 2 / (
        torch.ones(C - 1, device=device)
        + torch.arange(C - 1, 0, -1, device=device).float()
    )
else:
    s = torch.ones(C - 1, device=device)

# %% [markdown]
# Jacobi diffusion process converges to Beta stationary distribution, a univariate special case of Dirichlet distribution. Using the connection between Beta distribution and Dirichlet distribution, we construct a
# multivariate diffusion process on probability simplex that converges to Dirichlet distribution with k − 1 independent univariate Jacobi diffusion processes by a classical stick- breaking construction (see Paragraph 3.2 for more details)

# %%
sb = UnitStickBreakingTransform()

# %% [markdown]
# ### Computing Importance Sampling Weights
#
# Importance sampling is often needed to stabilize the training of diffusion model with likelihood weighting, since the scores for the forward diffusion transition density functions are usually large when time is small. Importance sampling is thus used as a variance reduction technique that samples time non-uniformly during training. By sampling time points where the scale of the score is higher more often and down-weight the sample loss accordingly, the variance of the gradient can be reduced. We determine the importance sampling weight based on the scale of the scores at each time point observed empirically. The choice of using importance sampling or not or the form of importance sampling weights depends on your applications.

# %%
n_time_steps = timepoints.shape[0]

time_dependent_cums = torch.zeros(n_time_steps).to(device)
time_dependent_counts = torch.zeros(n_time_steps).to(device)

for i, x in enumerate(weights_est_dl):
    x = binary_to_onehot(x.squeeze())
    random_t = torch.randint(0, n_time_steps, (x.shape[0],))
    order = np.random.permutation(np.arange(C))
    
    # There are two options for using presampled noise: 
    # First one is regular approach and second one is fast sampling (see Appendix A.4 for more info)
    perturbed_x, perturbed_x_grad = diffusion_factory(
        x, random_t, v_one, v_zero, v_one_loggrad, v_zero_loggrad, alpha, beta
    )
    # perturbed_x, perturbed_x_grad = diffusion_fast_flatdirichlet(x, random_t, v_one, v_one_loggrad)
    
    perturbed_x = perturbed_x.to(device)
    perturbed_x_grad = perturbed_x_grad.to(device)
    random_t = random_t.to(device)
    
    # Transform data from x space to v space, where diffusion happens
    order = np.random.permutation(np.arange(C))
    perturbed_v = sb._inverse(perturbed_x, prevent_nan=True).detach()

    # Computing score. gx_to_gv transforms gradient in x space to gradient in v space
    time_dependent_cums[random_t] += (
            (perturbed_v * (1 - perturbed_v)
                * s[(None,) * (x.ndim - 1)]
                * gx_to_gv(perturbed_x_grad, perturbed_x, compute_gradlogdet=False)** 2
            ).view(x.shape[0], -1).mean(dim=1).detach()
        )
        
    time_dependent_counts[random_t] += 1
    
time_dependent_weights = time_dependent_cums / time_dependent_counts
time_dependent_weights = time_dependent_weights / time_dependent_weights.mean()

# %% [markdown]
# The following plot verifies that our importance sampling weights are nice. It should be monotonic decreasing curve.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.plot(np.arange(1, n_time_steps + 1), time_dependent_weights.cpu())

# %% [markdown]
# ### Training

# %% [markdown]
# The following code trains the model and do validation check every 10 epochs.

# %%
#the score loss is computed in the v-space
def loss_fn(score, perturbed_x_grad, perturbed_x, important_sampling_weights=None):
    perturbed_v = sb._inverse(perturbed_x, prevent_nan=True).detach()
    if important_sampling_weights is not None:
        important_sampling_weights = 1/important_sampling_weights[
                    (...,) + (None,) * (x.ndim - 1)]
    else:
        important_sampling_weights = 1
    loss = torch.mean(
            torch.mean(
                important_sampling_weights
                * s[(None,) * (x.ndim - 1)]
                * perturbed_v * (1 - perturbed_v)
                * (gx_to_gv(
                        score, perturbed_x, create_graph=True, compute_gradlogdet=False
                    ) - gx_to_gv(perturbed_x_grad, perturbed_x, compute_gradlogdet=False)
                  ) ** 2,
                dim=(1))
        )
    return loss

# %%
# !mkdir checkpoints

# %%
torch.set_default_dtype(torch.float32)

# Defining a model
score_model = ScoreNet(channels=[64, 128, 256, 512], embed_dim=512)
score_model = score_model.to(device)
score_model.train()

# Defining optimizer
lr = 5e-4
optimizer = Adam(score_model.parameters(), lr=lr, weight_decay=1e-10)

timepoints = timepoints.to(device)

num_epochs = 50


run = wandb.init(
    entity=WANDB_ENTITY,
    project=WANDB_PROJECT,
    name="DDSM_BinMNIST_toy_example",
    config={
        "model": "ScoreNet with fourier embedding",
        "epochs": num_epochs,
        "batch_size": batch_size,
        "learning_rate": lr,
        "optimizer": "Adam",
        "experiment_description": "Toy example of DDSM on binarized MNIST dataset using presampled noise",
        "noise_presampling": "steps400.cat2.time4.0.samples10000.pth",
    }
)

for epoch in range(num_epochs):
    avg_loss = 0.0
    num_items = 0

    for x in tqdm.tqdm(training_dl, desc=f"Epoch {epoch+1}/{num_epochs}"):
        x = binary_to_onehot(x.squeeze())
        random_t = torch.LongTensor(
            np.random.choice(
                np.arange(n_time_steps),
                size=x.shape[0],
                p=(
                    torch.sqrt(time_dependent_weights)
                    / torch.sqrt(time_dependent_weights).sum()
                )
                .cpu()
                .detach()
                .numpy(),
            )
        ).to(device)
        
        # Similarly to computing importance sampling weights, there are two options 
        perturbed_x, perturbed_x_grad = diffusion_factory(
            x, random_t, v_one, v_zero, v_one_loggrad, v_zero_loggrad, alpha, beta
        )
        # perturbed_x, perturbed_x_grad = diffusion_fast_flatdirichlet(x, random_t, v_one, v_one_loggrad)
        
        perturbed_x = perturbed_x.to(device)
        perturbed_x_grad = perturbed_x_grad.to(device)
        random_t = random_t.to(device)
        random_timepoints = timepoints[random_t]
        
        # Doing score estimation via neural network
        score = score_model(perturbed_x, random_timepoints)
        
        # Computing loss function
        loss = loss_fn(score, perturbed_x_grad, perturbed_x, 
                       important_sampling_weights=(torch.sqrt(time_dependent_weights))[random_t])
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        avg_loss += loss.item() * x.shape[0]
        num_items += x.shape[0]

    # Print the averaged training loss so far.
    print("Average Train Loss: {:5f}".format(avg_loss / num_items))

    # Doing validation check every epoch.
    if epoch % 1 == 0:
        valid_avg_loss = 0.0
        valid_num_items = 0
        
        for x in valid_datasets:
            
            x = binary_to_onehot(x.squeeze())
            random_t = torch.LongTensor(
                np.random.choice(
                    np.arange(n_time_steps),
                    size=x.shape[0],
                    p=(
                        torch.sqrt(time_dependent_weights)
                        / torch.sqrt(time_dependent_weights).sum()
                    ).cpu().detach().numpy(),
                )
            ).to(device)
            
            perturbed_x, perturbed_x_grad = diffusion_factory(
                x, random_t, v_one, v_zero, v_one_loggrad, v_zero_loggrad, alpha, beta
            )
            # perturbed_x, perturbed_x_grad = diffusion_fast_flatdirichlet(x, random_t, v_one, v_one_loggrad)
            
            perturbed_x = perturbed_x.to(device)
            perturbed_x_grad = perturbed_x_grad.to(device)
            random_t = random_t.to(device)
            random_timepoints = timepoints[random_t]

            score = score_model(perturbed_x, random_timepoints)            
            loss = loss_fn(score, perturbed_x_grad, perturbed_x, 
                       important_sampling_weights=(torch.sqrt(time_dependent_weights))[random_t])

            valid_avg_loss += loss.item() * x.shape[0]
            valid_num_items += x.shape[0]

        print("Average Val Loss: {:5f}".format(valid_avg_loss / valid_num_items))

        run.log(
            {
                "train/loss": avg_loss / num_items,
                "val/loss": valid_avg_loss / valid_num_items,
                "epoch": epoch + 1,
            },
            step=epoch + 1,
            commit=True,
        )

model_path = f"checkpoints/score_model_binmnist_epoch{num_epochs}.pth"

torch.save(score_model.state_dict(), model_path)

model_artifact = wandb.Artifact(
    name="score_model_binmnist",
    type="model",
    description="Trained ScoreNet model on binarized MNIST using DDSM",
)
model_artifact.add_file(model_path)
run.log_artifact(model_artifact)

run.finish()
# Out:
# wandb: Currently logged in as: golubevva (golubevva-hse-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/Users/golubevva/Projects/bioinformatics-research/repos/ddsm/wandb/run-20260106_023336-aorvsx9p</code>
# Syncing run <strong><a href='https://wandb.ai/golubevva-hse-university/DDSM_testing/runs/aorvsx9p' target="_blank">DDSM_BinMNIST_toy_example</a></strong> to <a href='https://wandb.ai/golubevva-hse-university/DDSM_testing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/golubevva-hse-university/DDSM_testing' target="_blank">https://wandb.ai/golubevva-hse-university/DDSM_testing</a>
#  View run at <a href='https://wandb.ai/golubevva-hse-university/DDSM_testing/runs/aorvsx9p' target="_blank">https://wandb.ai/golubevva-hse-university/DDSM_testing/runs/aorvsx9p</a>
# Epoch 1/50: 100%|██████████| 1563/1563 [02:09<00:00, 12.12it/s]
# Average Train Loss: 0.985438
# Average Val Loss: 0.399629
# Epoch 2/50: 100%|██████████| 1563/1563 [02:12<00:00, 11.82it/s]
# Average Train Loss: 0.300957
# Average Val Loss: 0.234381
# Epoch 3/50: 100%|██████████| 1563/1563 [02:13<00:00, 11.71it/s]
# Average Train Loss: 0.208844
# Average Val Loss: 0.174839
# Epoch 4/50: 100%|██████████| 1563/1563 [02:05<00:00, 12.47it/s]
# Average Train Loss: 0.171825
# Average Val Loss: 0.157017
# Epoch 5/50: 100%|██████████| 1563/1563 [02:01<00:00, 12.92it/s]
# Average Train Loss: 0.154819
# Average Val Loss: 0.149429
# Epoch 6/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.98it/s]
# Average Train Loss: 0.147384
# Average Val Loss: 0.142928
# Epoch 7/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.95it/s]
# Average Train Loss: 0.141413
# Average Val Loss: 0.139180
# Epoch 8/50: 100%|██████████| 1563/1563 [02:01<00:00, 12.86it/s]
# Average Train Loss: 0.139001
# Average Val Loss: 0.136674
# Epoch 9/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.93it/s]
# Average Train Loss: 0.135413
# Average Val Loss: 0.140156
# Epoch 10/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.93it/s]
# Average Train Loss: 0.134796
# Average Val Loss: 0.129802
# Epoch 11/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.93it/s]
# Average Train Loss: 0.132187
# Average Val Loss: 0.131151
# Epoch 12/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.97it/s]
# Average Train Loss: 0.130764
# Average Val Loss: 0.134304
# Epoch 13/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.94it/s]
# Average Train Loss: 0.129870
# Average Val Loss: 0.127407
# Epoch 14/50: 100%|██████████| 1563/1563 [02:01<00:00, 12.91it/s]
# Average Train Loss: 0.127900
# Average Val Loss: 0.127490
# Epoch 15/50: 100%|██████████| 1563/1563 [02:02<00:00, 12.80it/s]
# Average Train Loss: 0.128359
# Average Val Loss: 0.129700
# Epoch 16/50: 100%|██████████| 1563/1563 [02:01<00:00, 12.91it/s]
# Average Train Loss: 0.127093
# Average Val Loss: 0.124256
# Epoch 17/50: 100%|██████████| 1563/1563 [02:00<00:00, 13.00it/s]
# Average Train Loss: 0.125657
# Average Val Loss: 0.124972
# Epoch 18/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.99it/s]
# Average Train Loss: 0.125588
# Average Val Loss: 0.126862
# Epoch 19/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.94it/s]
# Average Train Loss: 0.124436
# Average Val Loss: 0.125470
# Epoch 20/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.95it/s]
# Average Train Loss: 0.123708
# Average Val Loss: 0.122285
# Epoch 21/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.95it/s]
# Average Train Loss: 0.124279
# Average Val Loss: 0.128569
# Epoch 22/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.95it/s]
# Average Train Loss: 0.123128
# Average Val Loss: 0.126184
# Epoch 23/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.92it/s]
# Average Train Loss: 0.122709
# Average Val Loss: 0.121948
# Epoch 24/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.95it/s]
# Average Train Loss: 0.122346
# Average Val Loss: 0.120457
# Epoch 25/50: 100%|██████████| 1563/1563 [02:01<00:00, 12.86it/s]
# Average Train Loss: 0.121959
# Average Val Loss: 0.122214
# Epoch 26/50: 100%|██████████| 1563/1563 [02:01<00:00, 12.88it/s]
# Average Train Loss: 0.122219
# Average Val Loss: 0.121471
# Epoch 27/50: 100%|██████████| 1563/1563 [01:59<00:00, 13.05it/s]
# Average Train Loss: 0.121491
# Average Val Loss: 0.122852
# Epoch 28/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.97it/s]
# Average Train Loss: 0.120766
# Average Val Loss: 0.121387
# Epoch 29/50: 100%|██████████| 1563/1563 [01:59<00:00, 13.05it/s]
# Average Train Loss: 0.121185
# Average Val Loss: 0.121657
# Epoch 30/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.99it/s]
# Average Train Loss: 0.120136
# Average Val Loss: 0.121286
# Epoch 31/50: 100%|██████████| 1563/1563 [02:00<00:00, 13.00it/s]
# Average Train Loss: 0.120695
# Average Val Loss: 0.123265
# Epoch 32/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.99it/s]
# Average Train Loss: 0.120280
# Average Val Loss: 0.120899
# Epoch 33/50: 100%|██████████| 1563/1563 [01:59<00:00, 13.06it/s]
# Average Train Loss: 0.120074
# Average Val Loss: 0.118773
# Epoch 34/50: 100%|██████████| 1563/1563 [01:59<00:00, 13.03it/s]
# Average Train Loss: 0.120009
# Average Val Loss: 0.119598
# Epoch 35/50: 100%|██████████| 1563/1563 [02:01<00:00, 12.90it/s]
# Average Train Loss: 0.119411
# Average Val Loss: 0.121482
# Epoch 36/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.99it/s]
# Average Train Loss: 0.119763
# Average Val Loss: 0.120201
# Epoch 37/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.96it/s]
# Average Train Loss: 0.118675
# Average Val Loss: 0.118313
# Epoch 38/50: 100%|██████████| 1563/1563 [01:59<00:00, 13.04it/s]
# Average Train Loss: 0.118423
# Average Val Loss: 0.117852
# Epoch 39/50: 100%|██████████| 1563/1563 [02:00<00:00, 13.01it/s]
# Average Train Loss: 0.118686
# Average Val Loss: 0.118302
# Epoch 40/50: 100%|██████████| 1563/1563 [02:00<00:00, 13.01it/s]
# Average Train Loss: 0.118206
# Average Val Loss: 0.118599
# Epoch 41/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.96it/s]
# Average Train Loss: 0.118708
# Average Val Loss: 0.118876
# Epoch 42/50: 100%|██████████| 1563/1563 [02:02<00:00, 12.76it/s]
# Average Train Loss: 0.117620
# Average Val Loss: 0.118826
# Epoch 43/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.98it/s]
# Average Train Loss: 0.117681
# Average Val Loss: 0.119077
# Epoch 44/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.95it/s]
# Average Train Loss: 0.118491
# Average Val Loss: 0.118821
# Epoch 45/50: 100%|██████████| 1563/1563 [01:59<00:00, 13.06it/s]
# Average Train Loss: 0.117633
# Average Val Loss: 0.118612
# Epoch 46/50: 100%|██████████| 1563/1563 [01:59<00:00, 13.05it/s]
# Average Train Loss: 0.117396
# Average Val Loss: 0.116964
# Epoch 47/50: 100%|██████████| 1563/1563 [02:00<00:00, 12.99it/s]
# Average Train Loss: 0.118042
# Average Val Loss: 0.116964
# Epoch 48/50: 100%|██████████| 1563/1563 [01:59<00:00, 13.03it/s]
# Average Train Loss: 0.117618
# Average Val Loss: 0.118149
# Epoch 49/50: 100%|██████████| 1563/1563 [01:59<00:00, 13.04it/s]
# Average Train Loss: 0.117477
# Average Val Loss: 0.118157
# Epoch 50/50: 100%|██████████| 1563/1563 [02:00<00:00, 13.00it/s]
# Average Train Loss: 0.116899
# Average Val Loss: 0.116506
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train/loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/loss</td><td>█▄▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>50</td></tr><tr><td>train/loss</td><td>0.1169</td></tr><tr><td>val/loss</td><td>0.11651</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">DDSM_BinMNIST_toy_example</strong> at: <a href='https://wandb.ai/golubevva-hse-university/DDSM_testing/runs/aorvsx9p' target="_blank">https://wandb.ai/golubevva-hse-university/DDSM_testing/runs/aorvsx9p</a><br> View project at: <a href='https://wandb.ai/golubevva-hse-university/DDSM_testing' target="_blank">https://wandb.ai/golubevva-hse-university/DDSM_testing</a><br>Synced 4 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260106_023336-aorvsx9p/logs</code>

# %% [markdown]
# ### Sampling Examples from Dataset.

# %% [markdown]
# Let's sample a few examples from the model by using simple Euler-Maruyama sampler.

# %%
# generate samples from trained model
torch.set_default_dtype(torch.float32)
score_model.eval()

sample_batch_size = 64 
sampler = Euler_Maruyama_sampler ## Generate samples using the specified sampler.

samples = sampler(score_model, (28, 28, 2),
                        batch_size=sample_batch_size,
                        max_time= 4,
                        min_time=0.01, 
                        num_steps=100, 
                        eps=1e-5,
                        device=device)

samples = samples.clamp(0.0, 1.0)
sample_grid = make_grid(samples[:,None, :,:,0].detach().cpu(), nrow=int(np.sqrt(sample_batch_size)))

plt.figure(figsize=(6,6))
plt.axis('off')
plt.imshow(sample_grid.permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.show()
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 19.12it/s]

# %% [markdown]
# We also propose technique called **time dialation** to improve sample quality (see Appendix A.5 and B.9).
#
# Comparing to unbiasedly sample from the learned model distribution, it is often desirable to sample near the high probability density regions, which often corresponds to higher quality samples in suitable application. Time dilation is applicable to reverse diffusion sampling without modifying the score model, when a flat distribution such as the flat Dirichlet distribution is the stationary distribution. Our sampler implementation support time dilation technique out-of-box.

# %%
#generate samples with time dilation

samples = sampler(
    score_model,
    (28, 28, 2),
    batch_size=sample_batch_size,
    max_time=4.0,
    min_time=0.02,
    num_steps=200,
    time_dilation=8,
    time_dilation_start_time=None,
    eps=1e-5,
    device=device,
)

## Sample visualization.
samples = samples.clamp(0.0, 1.0)
sample_grid = make_grid(samples[:,None, :,:,0].detach().cpu(), nrow=int(np.sqrt(sample_batch_size)))

plt.figure(figsize=(6,6))
plt.axis('off')
plt.imshow(sample_grid.permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.show()
# Out:
# 100%|██████████| 1600/1600 [01:25<00:00, 18.67it/s]

# %% [markdown]
# ### Computing Negative Log Likelihood (ELBO) in Discrete Space
#
# We can estimate likelihood using probability flow ODE. Our formulation allows both computing the likelihood from
# the continuous distribution over the simplex, and computing a variation lower-bound of the likelihood of discrete data. The ELBO formulation is chosen so that the diffusion model training will also minimize the variational gap of this ELBO, which reduces to the KL divergence between the forward diffusion density and the reverse diffusion density up to a constant when minimum time is close to zero. The following code estimates ELBO based on test data.

# %%
# compute NLL (ELBO) in discrete space
diffusion_factory_fn = lambda x, time_inds : diffusion_factory(x, time_inds, v_one, v_zero,
                                        v_one_loggrad, v_zero_loggrad, alpha, beta)

alpha = torch.Tensor([1.0])
beta = torch.Tensor([1.0])

def ELBO(x, score_model, diffusion_factory_fn, min_time, max_time, device="cuda", elbo_only=True):
    perturbed_x, _ = diffusion_factory_fn(x.cpu(), torch.zeros(x.shape[0]).long())
    perturbed_x = perturbed_x.to(device)
    x = x.to(device)
    v = sb._inverse(x, prevent_nan=False)
    perturbed_v = sb._inverse(perturbed_x, prevent_nan=False)

    z, loglik = ode_likelihood(
        perturbed_v, score_model,
        eps=1e-5, min_time=min_time, max_time=max_time, device=device,
        alpha=None, beta=None, speed_balanced=speed_balanced)
    N = np.prod(x.shape[1:-1])
    loglik = loglik / N

    loglikx = (torch.log(perturbed_x) * (x == 1)).sum(-1).mean()

    torch.set_default_dtype(torch.float32)

    qlog = jacobi_diffusion_density(
        v.float(), perturbed_v.float(), min_time,
        alpha.to(device), beta.to(device),
        order=1000,
        speed_balanced=speed_balanced,
    ).log()
    
    for i, (a, b) in enumerate(zip(alpha.to(device), beta.to(device))):
        B = Beta(a, b)
        nanmask = torch.isnan(qlog[..., i])
        qlog[..., i][nanmask] = B.log_prob(perturbed_v[..., i][nanmask].float())
        
    qlog = (qlog.sum(-1) + sb.log_abs_det_jacobian(perturbed_v)).mean().float()
    torch.set_default_dtype(torch.float32)

    elbo = loglik + loglikx - qlog
    if elbo_only:
        return elbo
    else:
        return elbo, loglik, loglikx, qlog

# %%
score_model.to(device)
score_model.eval()

all_bpds = 0.0
all_items = 0
min_time = timepoints[0].item()
max_time = timepoints[-1].item()



# note that as the NLL estimate used the stochastic Huchinson's trace estimator
# it generally requires multiple passes to obtain a stable estimate
for x in test_dl:
    x = binary_to_onehot(x).squeeze()
    
    elbo = ELBO(x, score_model, diffusion_factory_fn, min_time, max_time, device=device)
    bpd = -(elbo.cpu().detach().numpy()) / np.log(2)
    all_bpds += bpd.sum()
    all_items += bpd.shape[0]
    print("Average bits: {:5f}".format(all_bpds / all_items))
    print("Average nats: {:5f}".format(all_bpds / all_items * np.log(2)))
# Out:
# Number of function evaluations: 263
# Average bits: 0.124395
# Average nats: 0.086224
# Number of function evaluations: 272
# Average bits: 0.128734
# Average nats: 0.089232
# Number of function evaluations: 260
# Average bits: 0.113292
# Average nats: 0.078528
# Number of function evaluations: 263
# Average bits: 0.141731
# Average nats: 0.098240
# Number of function evaluations: 257
# Average bits: 0.149708
# Average nats: 0.103770
# Number of function evaluations: 260
# Average bits: 0.156243
# Average nats: 0.108299
# Number of function evaluations: 266
# Average bits: 0.168320
# Average nats: 0.116671
# Number of function evaluations: 257
# Average bits: 0.174854
# Average nats: 0.121200
# Number of function evaluations: 284
# Average bits: 0.173735
# Average nats: 0.120424
# Number of function evaluations: 263
# Average bits: 0.183084
# Average nats: 0.126904
# Number of function evaluations: 272
# Average bits: 0.172320
# Average nats: 0.119443
# Number of function evaluations: 260
# Average bits: 0.173376
# Average nats: 0.120175
# Number of function evaluations: 266
# Average bits: 0.177740
# Average nats: 0.123200
# Number of function evaluations: 266
# Average bits: 0.175690
# Average nats: 0.121779
# Number of function evaluations: 269
# Average bits: 0.177446
# Average nats: 0.122996
# Number of function evaluations: 263
# Average bits: 0.176666
# Average nats: 0.122456
# Number of function evaluations: 266
# Average bits: 0.173852
# Average nats: 0.120505
# Number of function evaluations: 266
# Average bits: 0.177951
# Average nats: 0.123346
# Number of function evaluations: 272
# Average bits: 0.178352
# Average nats: 0.123624
# Number of function evaluations: 266
# Average bits: 0.178034
# Average nats: 0.123404
# Number of function evaluations: 272
# Average bits: 0.179548
# Average nats: 0.124453
# Number of function evaluations: 260
# Average bits: 0.178408
# Average nats: 0.123663
# Number of function evaluations: 278
# Average bits: 0.181497
# Average nats: 0.125804
# Number of function evaluations: 257
# Average bits: 0.180262
# Average nats: 0.124948
# Number of function evaluations: 269
# Average bits: 0.180068
# Average nats: 0.124814
# Number of function evaluations: 269
# Average bits: 0.180587
# Average nats: 0.125173
# Number of function evaluations: 263
# Average bits: 0.183828
# Average nats: 0.127420
# Number of function evaluations: 266
# Average bits: 0.182291
# Average nats: 0.126354
# Number of function evaluations: 263
# Average bits: 0.181896
# Average nats: 0.126081
# Number of function evaluations: 263
# Average bits: 0.183487
# Average nats: 0.127183
# Number of function evaluations: 272
# Average bits: 0.180617
# Average nats: 0.125194
# Number of function evaluations: 263
# Average bits: 0.180814
# Average nats: 0.125330
# Number of function evaluations: 269
# Average bits: 0.179859
# Average nats: 0.124669
# Number of function evaluations: 260
# Average bits: 0.179959
# Average nats: 0.124738
# Number of function evaluations: 260
# Average bits: 0.182578
# Average nats: 0.126553
# Number of function evaluations: 266
# Average bits: 0.180465
# Average nats: 0.125089
# Number of function evaluations: 266
# Average bits: 0.182978
# Average nats: 0.126831
# Number of function evaluations: 266
# Average bits: 0.182238
# Average nats: 0.126317
# Number of function evaluations: 272
# Average bits: 0.181720
# Average nats: 0.125959
# Number of function evaluations: 269
# Average bits: 0.180980
# Average nats: 0.125446
# Number of function evaluations: 269
# Average bits: 0.182910
# Average nats: 0.126784
# Number of function evaluations: 266
# Average bits: 0.180634
# Average nats: 0.125206
# Number of function evaluations: 266
# Average bits: 0.178369
# Average nats: 0.123636
# Number of function evaluations: 260
# Average bits: 0.179905
# Average nats: 0.124701
# Number of function evaluations: 272
# Average bits: 0.181060
# Average nats: 0.125501
# Number of function evaluations: 266
# Average bits: 0.180763
# Average nats: 0.125296
# Number of function evaluations: 266
# Average bits: 0.180047
# Average nats: 0.124799
# Number of function evaluations: 275
# Average bits: 0.179655
# Average nats: 0.124527
# Number of function evaluations: 266
# Average bits: 0.178816
# Average nats: 0.123945
# Number of function evaluations: 272
# Average bits: 0.178525
# Average nats: 0.123744
# Number of function evaluations: 260
# Average bits: 0.176211
# Average nats: 0.122140
# Number of function evaluations: 266
# Average bits: 0.176618
# Average nats: 0.122422
# Number of function evaluations: 260
# Average bits: 0.176256
# Average nats: 0.122171
# Number of function evaluations: 266
# Average bits: 0.176751
# Average nats: 0.122515
# Number of function evaluations: 263
# Average bits: 0.176311
# Average nats: 0.122210
# Number of function evaluations: 269
# Average bits: 0.176437
# Average nats: 0.122297
# Number of function evaluations: 260
# Average bits: 0.177301
# Average nats: 0.122896
# Number of function evaluations: 275
# Average bits: 0.179024
# Average nats: 0.124090
# Number of function evaluations: 260
# Average bits: 0.180454
# Average nats: 0.125081
# Number of function evaluations: 263
# Average bits: 0.180785
# Average nats: 0.125311
# Number of function evaluations: 266
# Average bits: 0.181137
# Average nats: 0.125555
# Number of function evaluations: 257
# Average bits: 0.181641
# Average nats: 0.125904
# Number of function evaluations: 263
# Average bits: 0.182105
# Average nats: 0.126226
# Number of function evaluations: 263
# Average bits: 0.181661
# Average nats: 0.125918
# Number of function evaluations: 257
# Average bits: 0.182611
# Average nats: 0.126576
# Number of function evaluations: 278
# Average bits: 0.183364
# Average nats: 0.127098
# Number of function evaluations: 266
# Average bits: 0.182622
# Average nats: 0.126584
# Number of function evaluations: 257
# Average bits: 0.181331
# Average nats: 0.125689
# Number of function evaluations: 275
# Average bits: 0.181381
# Average nats: 0.125724
# Number of function evaluations: 272
# Average bits: 0.182346
# Average nats: 0.126393
# Number of function evaluations: 272
# Average bits: 0.183235
# Average nats: 0.127009
# Number of function evaluations: 260
# Average bits: 0.184135
# Average nats: 0.127633
# Number of function evaluations: 263
# Average bits: 0.184176
# Average nats: 0.127661
# Number of function evaluations: 257
# Average bits: 0.183982
# Average nats: 0.127526
# Number of function evaluations: 272
# Average bits: 0.183237
# Average nats: 0.127010
# Number of function evaluations: 272
# Average bits: 0.184014
# Average nats: 0.127548
# Number of function evaluations: 263
# Average bits: 0.183487
# Average nats: 0.127183
# Number of function evaluations: 275
# Average bits: 0.183847
# Average nats: 0.127433
# Number of function evaluations: 266
# Average bits: 0.182842
# Average nats: 0.126737
# Number of function evaluations: 266
# Average bits: 0.182934
# Average nats: 0.126800
# Number of function evaluations: 266
# Average bits: 0.183061
# Average nats: 0.126889
# Number of function evaluations: 269
# Average bits: 0.181965
# Average nats: 0.126128
# Number of function evaluations: 266
# Average bits: 0.183378
# Average nats: 0.127108
# Number of function evaluations: 281
# Average bits: 0.182927
# Average nats: 0.126796
# Number of function evaluations: 269
# Average bits: 0.182032
# Average nats: 0.126175
# Number of function evaluations: 272
# Average bits: 0.181854
# Average nats: 0.126051
# Number of function evaluations: 266
# Average bits: 0.182261
# Average nats: 0.126334
# Number of function evaluations: 266
# Average bits: 0.182249
# Average nats: 0.126325
# Number of function evaluations: 263
# Average bits: 0.182205
# Average nats: 0.126295
# Number of function evaluations: 260
# Average bits: 0.181561
# Average nats: 0.125849
# Number of function evaluations: 260
# Average bits: 0.181610
# Average nats: 0.125883
# Number of function evaluations: 281
# Average bits: 0.180591
# Average nats: 0.125176
# Number of function evaluations: 266
# Average bits: 0.180130
# Average nats: 0.124857
# Number of function evaluations: 269
# Average bits: 0.181408
# Average nats: 0.125742
# Number of function evaluations: 263
# Average bits: 0.182434
# Average nats: 0.126454
# Number of function evaluations: 269
# Average bits: 0.181825
# Average nats: 0.126031
# Number of function evaluations: 269
# Average bits: 0.181393
# Average nats: 0.125732
# Number of function evaluations: 263
# Average bits: 0.181702
# Average nats: 0.125947
# Number of function evaluations: 260
# Average bits: 0.182748
# Average nats: 0.126671
# Number of function evaluations: 266
# Average bits: 0.184001
# Average nats: 0.127540
# Number of function evaluations: 272
# Average bits: 0.183759
# Average nats: 0.127372
# Number of function evaluations: 263
# Average bits: 0.183462
# Average nats: 0.127166
# Number of function evaluations: 263
# Average bits: 0.183657
# Average nats: 0.127301
# Number of function evaluations: 269
# Average bits: 0.183971
# Average nats: 0.127519
# Number of function evaluations: 266
# Average bits: 0.184254
# Average nats: 0.127715
# Number of function evaluations: 275
# Average bits: 0.184063
# Average nats: 0.127583
# Number of function evaluations: 257
# Average bits: 0.183929
# Average nats: 0.127490
# Number of function evaluations: 272
# Average bits: 0.183987
# Average nats: 0.127530
# Number of function evaluations: 260
# Average bits: 0.185101
# Average nats: 0.128302
# Number of function evaluations: 260
# Average bits: 0.185222
# Average nats: 0.128386
# Number of function evaluations: 275
# Average bits: 0.184492
# Average nats: 0.127880
# Number of function evaluations: 266
# Average bits: 0.184402
# Average nats: 0.127817
# Number of function evaluations: 269
# Average bits: 0.184963
# Average nats: 0.128206
# Number of function evaluations: 260
# Average bits: 0.185564
# Average nats: 0.128623
# Number of function evaluations: 263
# Average bits: 0.185386
# Average nats: 0.128500
# Number of function evaluations: 272
# Average bits: 0.185073
# Average nats: 0.128283
# Number of function evaluations: 266
# Average bits: 0.185411
# Average nats: 0.128517
# Number of function evaluations: 266
# Average bits: 0.185038
# Average nats: 0.128259
# Number of function evaluations: 260
# Average bits: 0.184341
# Average nats: 0.127775
# Number of function evaluations: 266
# Average bits: 0.184411
# Average nats: 0.127824
# Number of function evaluations: 266
# Average bits: 0.184365
# Average nats: 0.127792
# Number of function evaluations: 266
# Average bits: 0.184152
# Average nats: 0.127644
# Number of function evaluations: 263
# Average bits: 0.183762
# Average nats: 0.127374
# Number of function evaluations: 269
# Average bits: 0.183442
# Average nats: 0.127152
# Number of function evaluations: 254
# Average bits: 0.184054
# Average nats: 0.127577
# Number of function evaluations: 269
# Average bits: 0.183567
# Average nats: 0.127239
# Number of function evaluations: 269
# Average bits: 0.184079
# Average nats: 0.127594
# Number of function evaluations: 272
# Average bits: 0.184221
# Average nats: 0.127693
# Number of function evaluations: 269
# Average bits: 0.184668
# Average nats: 0.128002
# Number of function evaluations: 266
# Average bits: 0.184340
# Average nats: 0.127775
# Number of function evaluations: 263
# Average bits: 0.183594
# Average nats: 0.127257
# Number of function evaluations: 263
# Average bits: 0.183348
# Average nats: 0.127087
# Number of function evaluations: 263
# Average bits: 0.183163
# Average nats: 0.126959
# Number of function evaluations: 266
# Average bits: 0.183640
# Average nats: 0.127290
# Number of function evaluations: 266
# Average bits: 0.183833
# Average nats: 0.127423
# Number of function evaluations: 257
# Average bits: 0.183683
# Average nats: 0.127319
# Number of function evaluations: 272
# Average bits: 0.183375
# Average nats: 0.127106
# Number of function evaluations: 272
# Average bits: 0.183348
# Average nats: 0.127087
# Number of function evaluations: 269
# Average bits: 0.182838
# Average nats: 0.126733
# Number of function evaluations: 263
# Average bits: 0.182705
# Average nats: 0.126641
# Number of function evaluations: 263
# Average bits: 0.182928
# Average nats: 0.126796
# Number of function evaluations: 260
# Average bits: 0.182611
# Average nats: 0.126576
# Number of function evaluations: 272
# Average bits: 0.182702
# Average nats: 0.126639
# Number of function evaluations: 272
# Average bits: 0.182763
# Average nats: 0.126682
# Number of function evaluations: 266
# Average bits: 0.182827
# Average nats: 0.126726
# Number of function evaluations: 269
# Average bits: 0.183002
# Average nats: 0.126848
# Number of function evaluations: 263
# Average bits: 0.182813
# Average nats: 0.126717
# Number of function evaluations: 272
# Average bits: 0.183087
# Average nats: 0.126907
# Number of function evaluations: 278
# Average bits: 0.182840
# Average nats: 0.126735
# Number of function evaluations: 272
# Average bits: 0.183177
# Average nats: 0.126968
# Number of function evaluations: 269
# Average bits: 0.183225
# Average nats: 0.127002
# Number of function evaluations: 269
# Average bits: 0.183050
# Average nats: 0.126881
# Number of function evaluations: 260
# Average bits: 0.183169
# Average nats: 0.126963
# Number of function evaluations: 263
# Average bits: 0.182688
# Average nats: 0.126630
# Number of function evaluations: 263
# Average bits: 0.182768
# Average nats: 0.126685
# Number of function evaluations: 272
# Average bits: 0.182732
# Average nats: 0.126660
# Number of function evaluations: 266
# Average bits: 0.183115
# Average nats: 0.126926
# Number of function evaluations: 263
# Average bits: 0.183141
# Average nats: 0.126944
# Number of function evaluations: 266
# Average bits: 0.182919
# Average nats: 0.126789
# Number of function evaluations: 281
# Average bits: 0.183474
# Average nats: 0.127175
# Number of function evaluations: 275
# Average bits: 0.183789
# Average nats: 0.127393
# Number of function evaluations: 269
# Average bits: 0.184438
# Average nats: 0.127843
# Number of function evaluations: 263
# Average bits: 0.183405
# Average nats: 0.127127
# Number of function evaluations: 272
# Average bits: 0.183517
# Average nats: 0.127204
# Number of function evaluations: 260
# Average bits: 0.183490
# Average nats: 0.127186
# Number of function evaluations: 263
# Average bits: 0.184218
# Average nats: 0.127690
# Number of function evaluations: 266
# Average bits: 0.184201
# Average nats: 0.127679
# Number of function evaluations: 269
# Average bits: 0.184236
# Average nats: 0.127702
# Number of function evaluations: 263
# Average bits: 0.184342
# Average nats: 0.127776
# Number of function evaluations: 266
# Average bits: 0.184349
# Average nats: 0.127781
# Number of function evaluations: 263
# Average bits: 0.185219
# Average nats: 0.128384
# Number of function evaluations: 278
# Average bits: 0.185127
# Average nats: 0.128320
# Number of function evaluations: 263
# Average bits: 0.185426
# Average nats: 0.128528
# Number of function evaluations: 266
# Average bits: 0.185311
# Average nats: 0.128448
# Number of function evaluations: 272
# Average bits: 0.185013
# Average nats: 0.128241
# Number of function evaluations: 257
# Average bits: 0.185319
# Average nats: 0.128453
# Number of function evaluations: 272
# Average bits: 0.185602
# Average nats: 0.128649
# Number of function evaluations: 263
# Average bits: 0.186156
# Average nats: 0.129033
# Number of function evaluations: 275
# Average bits: 0.185889
# Average nats: 0.128848
# Number of function evaluations: 269
# Average bits: 0.185910
# Average nats: 0.128863
# Number of function evaluations: 269
# Average bits: 0.185922
# Average nats: 0.128871
# Number of function evaluations: 275
# Average bits: 0.185994
# Average nats: 0.128921
# Number of function evaluations: 263
# Average bits: 0.185909
# Average nats: 0.128862
# Number of function evaluations: 269
# Average bits: 0.185964
# Average nats: 0.128900
# Number of function evaluations: 272
# Average bits: 0.185983
# Average nats: 0.128914
# Number of function evaluations: 278
# Average bits: 0.185741
# Average nats: 0.128746
# Number of function evaluations: 269
# Average bits: 0.185799
# Average nats: 0.128786
# Number of function evaluations: 272
# Average bits: 0.186023
# Average nats: 0.128941
# Number of function evaluations: 260
# Average bits: 0.186172
# Average nats: 0.129045
# Number of function evaluations: 266
# Average bits: 0.186303
# Average nats: 0.129135
# Number of function evaluations: 269
# Average bits: 0.185864
# Average nats: 0.128831
# Number of function evaluations: 272
# Average bits: 0.186185
# Average nats: 0.129053
# Number of function evaluations: 266
# Average bits: 0.186227
# Average nats: 0.129082
# Number of function evaluations: 266
# Average bits: 0.186267
# Average nats: 0.129110
# Number of function evaluations: 269
# Average bits: 0.185995
# Average nats: 0.128922
# Number of function evaluations: 281
# Average bits: 0.186005
# Average nats: 0.128929
# Number of function evaluations: 269
# Average bits: 0.185808
# Average nats: 0.128792
# Number of function evaluations: 263
# Average bits: 0.185911
# Average nats: 0.128864
# Number of function evaluations: 275
# Average bits: 0.185865
# Average nats: 0.128832
# Number of function evaluations: 275
# Average bits: 0.185881
# Average nats: 0.128843
# Number of function evaluations: 281
# Average bits: 0.185918
# Average nats: 0.128869
# Number of function evaluations: 260
# Average bits: 0.186095
# Average nats: 0.128991
# Number of function evaluations: 269
# Average bits: 0.186356
# Average nats: 0.129172
# Number of function evaluations: 266
# Average bits: 0.186640
# Average nats: 0.129369
# Number of function evaluations: 263
# Average bits: 0.186494
# Average nats: 0.129268
# Number of function evaluations: 269
# Average bits: 0.186418
# Average nats: 0.129215
# Number of function evaluations: 272
# Average bits: 0.186298
# Average nats: 0.129132
# Number of function evaluations: 263
# Average bits: 0.186194
# Average nats: 0.129060
# Number of function evaluations: 272
# Average bits: 0.185902
# Average nats: 0.128858
# Number of function evaluations: 266
# Average bits: 0.185251
# Average nats: 0.128406
# Number of function evaluations: 263
# Average bits: 0.184950
# Average nats: 0.128198
# Number of function evaluations: 260
# Average bits: 0.184924
# Average nats: 0.128179
# Number of function evaluations: 266
# Average bits: 0.184277
# Average nats: 0.127731
# Number of function evaluations: 263
# Average bits: 0.184123
# Average nats: 0.127624
# Number of function evaluations: 266
# Average bits: 0.183980
# Average nats: 0.127525
# Number of function evaluations: 260
# Average bits: 0.183507
# Average nats: 0.127197
# Number of function evaluations: 263
# Average bits: 0.183601
# Average nats: 0.127263
# Number of function evaluations: 275
# Average bits: 0.183860
# Average nats: 0.127442
# Number of function evaluations: 263
# Average bits: 0.183840
# Average nats: 0.127428
# Number of function evaluations: 269
# Average bits: 0.183721
# Average nats: 0.127346
# Number of function evaluations: 272
# Average bits: 0.183824
# Average nats: 0.127417
# Number of function evaluations: 275
# Average bits: 0.183334
# Average nats: 0.127078
# Number of function evaluations: 266
# Average bits: 0.183283
# Average nats: 0.127042
# Number of function evaluations: 269
# Average bits: 0.183449
# Average nats: 0.127157
# Number of function evaluations: 272
# Average bits: 0.183179
# Average nats: 0.126970
# Number of function evaluations: 266
# Average bits: 0.182837
# Average nats: 0.126733
# Number of function evaluations: 263
# Average bits: 0.182799
# Average nats: 0.126706
# Number of function evaluations: 269
# Average bits: 0.182877
# Average nats: 0.126760
# Number of function evaluations: 272
# Average bits: 0.182608
# Average nats: 0.126574
# Number of function evaluations: 275
# Average bits: 0.182027
# Average nats: 0.126172
# Number of function evaluations: 281
# Average bits: 0.182128
# Average nats: 0.126242
# Number of function evaluations: 266
# Average bits: 0.182490
# Average nats: 0.126493
# Number of function evaluations: 269
# Average bits: 0.182681
# Average nats: 0.126625
# Number of function evaluations: 254
# Average bits: 0.182803
# Average nats: 0.126709
# Number of function evaluations: 257
# Average bits: 0.182789
# Average nats: 0.126700
# Number of function evaluations: 266
# Average bits: 0.182465
# Average nats: 0.126475
# Number of function evaluations: 269
# Average bits: 0.182441
# Average nats: 0.126459
# Number of function evaluations: 266
# Average bits: 0.182221
# Average nats: 0.126306
# Number of function evaluations: 260
# Average bits: 0.182567
# Average nats: 0.126546
# Number of function evaluations: 269
# Average bits: 0.182715
# Average nats: 0.126648
# Number of function evaluations: 266
# Average bits: 0.182939
# Average nats: 0.126804
# Number of function evaluations: 266
# Average bits: 0.182647
# Average nats: 0.126601
# Number of function evaluations: 275
# Average bits: 0.182534
# Average nats: 0.126523
# Number of function evaluations: 263
# Average bits: 0.182376
# Average nats: 0.126413
# Number of function evaluations: 266
# Average bits: 0.182431
# Average nats: 0.126451
# Number of function evaluations: 272
# Average bits: 0.182234
# Average nats: 0.126315
# Number of function evaluations: 263
# Average bits: 0.182133
# Average nats: 0.126245
# Number of function evaluations: 263
# Average bits: 0.182286
# Average nats: 0.126351
# Number of function evaluations: 260
# Average bits: 0.182395
# Average nats: 0.126426
# Number of function evaluations: 254
# Average bits: 0.182572
# Average nats: 0.126549
# Number of function evaluations: 266
# Average bits: 0.182714
# Average nats: 0.126648
# Number of function evaluations: 266
# Average bits: 0.182346
# Average nats: 0.126393
# Number of function evaluations: 266
# Average bits: 0.182371
# Average nats: 0.126410
# Number of function evaluations: 266
# Average bits: 0.182502
# Average nats: 0.126501
# Number of function evaluations: 266
# Average bits: 0.182530
# Average nats: 0.126520
# Number of function evaluations: 266
# Average bits: 0.182228
# Average nats: 0.126311
# Number of function evaluations: 260
# Average bits: 0.182452
# Average nats: 0.126466
# Number of function evaluations: 260
# Average bits: 0.182259
# Average nats: 0.126332
# Number of function evaluations: 254
# Average bits: 0.182215
# Average nats: 0.126302
# Number of function evaluations: 260
# Average bits: 0.182060
# Average nats: 0.126195
# Number of function evaluations: 266
# Average bits: 0.181817
# Average nats: 0.126026
# Number of function evaluations: 290
# Average bits: 0.181798
# Average nats: 0.126013
# Number of function evaluations: 266
# Average bits: 0.181754
# Average nats: 0.125983
# Number of function evaluations: 263
# Average bits: 0.181754
# Average nats: 0.125982
# Number of function evaluations: 263
# Average bits: 0.181308
# Average nats: 0.125673
# Number of function evaluations: 266
# Average bits: 0.181465
# Average nats: 0.125782
# Number of function evaluations: 266
# Average bits: 0.181780
# Average nats: 0.126000
# Number of function evaluations: 260
# Average bits: 0.181607
# Average nats: 0.125880
# Number of function evaluations: 269
# Average bits: 0.181399
# Average nats: 0.125736
# Number of function evaluations: 269
# Average bits: 0.181176
# Average nats: 0.125582
# Number of function evaluations: 260
# Average bits: 0.181321
# Average nats: 0.125682
# Number of function evaluations: 269
# Average bits: 0.181556
# Average nats: 0.125845
# Number of function evaluations: 263
# Average bits: 0.181607
# Average nats: 0.125880
# Number of function evaluations: 275
# Average bits: 0.181573
# Average nats: 0.125857
# Number of function evaluations: 263
# Average bits: 0.181414
# Average nats: 0.125747
# Number of function evaluations: 263
# Average bits: 0.181449
# Average nats: 0.125771
# Number of function evaluations: 266
# Average bits: 0.181478
# Average nats: 0.125791
# Number of function evaluations: 266
# Average bits: 0.181085
# Average nats: 0.125519
# Number of function evaluations: 269
# Average bits: 0.180934
# Average nats: 0.125414
# Number of function evaluations: 269
# Average bits: 0.180840
# Average nats: 0.125349
# Number of function evaluations: 269
# Average bits: 0.180991
# Average nats: 0.125453
# Number of function evaluations: 269
# Average bits: 0.180790
# Average nats: 0.125314
# Number of function evaluations: 278
# Average bits: 0.180866
# Average nats: 0.125367
# Number of function evaluations: 269
# Average bits: 0.180635
# Average nats: 0.125207
# Number of function evaluations: 266
# Average bits: 0.180646
# Average nats: 0.125214
# Number of function evaluations: 266
# Average bits: 0.180654
# Average nats: 0.125220
# Number of function evaluations: 266
# Average bits: 0.181092
# Average nats: 0.125524
# Number of function evaluations: 272
# Average bits: 0.180958
# Average nats: 0.125431
# Number of function evaluations: 263
# Average bits: 0.180991
# Average nats: 0.125454
# Number of function evaluations: 272
# Average bits: 0.180889
# Average nats: 0.125383
# Number of function evaluations: 266
# Average bits: 0.180660
# Average nats: 0.125224
# Number of function evaluations: 269
# Average bits: 0.180601
# Average nats: 0.125183
# Number of function evaluations: 263
# Average bits: 0.180685
# Average nats: 0.125241
# Number of function evaluations: 260
# Average bits: 0.180780
# Average nats: 0.125307
# Number of function evaluations: 260
# Average bits: 0.180873
# Average nats: 0.125372
# Number of function evaluations: 257
# Average bits: 0.180764
# Average nats: 0.125296
# Number of function evaluations: 263
# Average bits: 0.180810
# Average nats: 0.125328
# Number of function evaluations: 254
# Average bits: 0.180534
# Average nats: 0.125136
# Number of function evaluations: 263
# Average bits: 0.180737
# Average nats: 0.125277
# Number of function evaluations: 263
# Average bits: 0.180667
# Average nats: 0.125229
# Number of function evaluations: 260
# Average bits: 0.180454
# Average nats: 0.125081
# Number of function evaluations: 266
# Average bits: 0.180188
# Average nats: 0.124897
# Number of function evaluations: 257
# Average bits: 0.179994
# Average nats: 0.124763
# Number of function evaluations: 266
# Average bits: 0.180065
# Average nats: 0.124812
# Number of function evaluations: 272
# Average bits: 0.180093
# Average nats: 0.124831
# Number of function evaluations: 266
# Average bits: 0.179896
# Average nats: 0.124694
# Number of function evaluations: 263
# Average bits: 0.180088
# Average nats: 0.124828
# Number of function evaluations: 263
# Average bits: 0.180048
# Average nats: 0.124800
# Number of function evaluations: 269
# Average bits: 0.180218
# Average nats: 0.124917
# Number of function evaluations: 272
# Average bits: 0.180328
# Average nats: 0.124994
# Number of function evaluations: 269
# Average bits: 0.180219
# Average nats: 0.124918
# Number of function evaluations: 287
# Average bits: 0.179868
# Average nats: 0.124675
# Number of function evaluations: 266
# Average bits: 0.180040
# Average nats: 0.124794
